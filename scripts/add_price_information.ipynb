# %% [markdown]
# Outline:
#
# Constraint insertion:
# - Min/max order quantity
# - Min/max purity (:=quality attribute)
# - Min/max price
#
# Error specifications and ranking:
# - Deviation metrics (ie. KL)
# - Filter out uncertain options (Toggle)
