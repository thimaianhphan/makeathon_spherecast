# %%
import sys
sys.path.insert(0, '.')

from backend.db import (
    get_companies,
    get_products,
    get_boms,
    get_bom_components,
    get_suppliers,
    get_supplier_products,
    batch,
)

# %%
get_suppliers()
# Out:
# [{'Id': 1, 'Name': 'ADM'},
#  {'Id': 2, 'Name': 'AIDP'},
#  {'Id': 3, 'Name': 'Actus Nutrition'},
#  {'Id': 4, 'Name': 'American Botanicals'},
#  {'Id': 5, 'Name': 'Ashland'},
#  {'Id': 6, 'Name': 'Balchem'},
#  {'Id': 7, 'Name': 'BulkSupplements'},
#  {'Id': 8, 'Name': 'Cambrex'},
#  {'Id': 9, 'Name': 'Capsuline'},
#  {'Id': 10, 'Name': 'Cargill'},
#  {'Id': 11, 'Name': 'Colorcon'},
#  {'Id': 12, 'Name': 'Custom Probiotics'},
#  {'Id': 13, 'Name': 'Darling Ingredients / Rousselot'},
#  {'Id': 14, 'Name': 'FutureCeuticals'},
#  {'Id': 15, 'Name': 'Gold Coast Ingredients'},
#  {'Id': 16, 'Name': 'IFF'},
#  {'Id': 17, 'Name': 'Icelandirect'},
#  {'Id': 18, 'Name': 'Ingredion'},
#  {'Id': 19, 'Name': 'Jost Chemical'},
#  {'Id': 20, 'Name': 'Koster Keunen'},
#  {'Id': 21, 'Name': 'Magtein / ThreoTech LLC'},
#  {'Id': 22, 'Name': 'Makers Nutrition'},
#  {'Id': 23, 'Name': 'Mueggenburg USA'},
#  {'Id': 24, 'Name': 'Nutra Blend'},
#  {'Id': 25, 'Name': 'Nutra Food Ingredients'},
#  {'Id': 26, 'Name': 'Nutri Avenue'},
#  {'Id': 27, 'Name': 'Prinova USA'},
#  {'Id': 28, 'Name': 'PureBulk'},
#  {'Id': 29, 'Name': 'Sawgrass Nutra Labs'},
#  {'Id': 30, 'Name': 'Sensient'},
#  {'Id': 31, 'Name': 'Source-Omega LLC'},
#  {'Id': 32, 'Name': 'Specialty Enzymes & Probiotics'},
#  {'Id': 33, 'Name': 'Spectrum Chemical'},
#  {'Id': 34, 'Name': 'Stauber'},
#  {'Id': 35, 'Name': 'Strahl & Pitsch'},
#  {'Id': 36, 'Name': 'TCI America'},
#  {'Id': 37, 'Name': 'Trace Minerals'},
#  {'Id': 38, 'Name': 'Univar Solutions'},
#  {'Id': 39, 'Name': 'Virginia Dare'},
#  {'Id': 40, 'Name': 'Vitaquest'}]

# %%
companies = get_companies()
print(f"{len(companies)} companies")
companies[:3]
# Out:
# 61 companies
# [{'Id': 1, 'Name': '21st Century'},
#  {'Id': 2, 'Name': 'ALL ONE'},
#  {'Id': 3, 'Name': 'AN PERFORMANCE'}]

# %%
products = get_products()
finished = get_products(type='finished-good')
raw = get_products(type='raw-material')
print(f"{len(products)} total | {len(finished)} finished-good | {len(raw)} raw-material")
products[:3]
# Out:
# 1025 total | 149 finished-good | 876 raw-material
# [{'Id': 48,
#   'SKU': 'FG-amazon-b0002wrqy4',
#   'CompanyId': 2,
#   'Type': 'finished-good',
#   'CompanyName': 'ALL ONE'},
#  {'Id': 57,
#   'SKU': 'FG-amazon-b007vwbm2u',
#   'CompanyId': 57,
#   'Type': 'finished-good',
#   'CompanyName': 'Vitacost'},
#  {'Id': 49,
#   'SKU': 'FG-amazon-b012t9ga6c',
#   'CompanyId': 38,
#   'Type': 'finished-good',
#   'CompanyName': 'Optimum Nutrition'}]

# %%
boms = get_boms()
print(f"{len(boms)} BOMs")
boms[:3]
# Out:
# 149 BOMs
# [{'BOMId': 48,
#   'ProducedSKU': 'FG-amazon-b0002wrqy4',
#   'CompanyName': 'ALL ONE'},
#  {'BOMId': 57,
#   'ProducedSKU': 'FG-amazon-b007vwbm2u',
#   'CompanyName': 'Vitacost'},
#  {'BOMId': 49,
#   'ProducedSKU': 'FG-amazon-b012t9ga6c',
#   'CompanyName': 'Optimum Nutrition'}]

# %%
# Components for the first BOM
first_bom_id = boms[0]['BOMId']
components = get_bom_components(first_bom_id)
print(f"BOM {first_bom_id} ({boms[0]['ProducedSKU']}) has {len(components)} components")
components
# Out:
# BOM 48 (FG-amazon-b0002wrqy4) has 21 components
# [{'BOMId': 48,
#   'ConsumedSKU': 'RM-C2-ascorbic-acid-4823fabf',
#   'Type': 'raw-material',
#   'CompanyName': 'ALL ONE'},
#  {'BOMId': 48,
#   'ConsumedSKU': 'RM-C2-beta-carotene-bb90cd60',
#   'Type': 'raw-material',
#   'CompanyName': 'ALL ONE'},
#  {'BOMId': 48,
#   'ConsumedSKU': 'RM-C2-choline-bitartrate-296d4da4',
#   'Type': 'raw-material',
#   'CompanyName': 'ALL ONE'},
#  {'BOMId': 48,
#   'ConsumedSKU': 'RM-C2-cyanocobalamin-c2d9669b',
#   'Type': 'raw-material',
#   'CompanyName': 'ALL ONE'},
#  {'BOMId': 48,
#   'ConsumedSKU': 'RM-C2-d-alpha-tocopheryl-succinate-532e67fd',
#   'Type': 'raw-material',
#   'CompanyName': 'ALL ONE'},
#  {'BOMId': 48,
#   'ConsumedSKU': 'RM-C2-d-calcium-pantothenate-bc49e976',
#   'Type': 'raw-material',
#   'CompanyName': 'ALL ONE'},
#  {'BOMId': 48,
#   'ConsumedSKU': 'RM-C2-hesperidin-complex-a26e0bcd',
#   'Type': 'raw-material',
#   'CompanyName': 'ALL ONE'},
#  {'BOMId': 48,
#   'ConsumedSKU': 'RM-C2-inositol-a10dfe66',
#   'Type': 'raw-material',
#   'CompanyName': 'ALL ONE'},
#  {'BOMId': 48,
#   'ConsumedSKU': 'RM-C2-lemon-bioflavonoid-complex-0eeb9802',
#   'Type': 'raw-material',
#   'CompanyName': 'ALL ONE'},
#  {'BOMId': 48,
#   'ConsumedSKU': 'RM-C2-manganese-2947a710',
#   'Type': 'raw-material',
#   'CompanyName': 'ALL ONE'},
#  {'BOMId': 48,
#   'ConsumedSKU': 'RM-C2-niacinamide-c27eb0fe',
#   'Type': 'raw-material',
#   'CompanyName': 'ALL ONE'},
#  {'BOMId': 48,
#   'ConsumedSKU': 'RM-C2-para-amino-benzoic-acid-b19c9ed7',
#   'Type': 'raw-material',
#   'CompanyName': 'ALL ONE'},
#  {'BOMId': 48,
#   'ConsumedSKU': 'RM-C2-potassium-alginate-ab91bdcc',
#   'Type': 'raw-material',
#   'CompanyName': 'ALL ONE'},
#  {'BOMId': 48,
#   'ConsumedSKU': 'RM-C2-pyridoxine-hcl-0a843bcb',
#   'Type': 'raw-material',
#   'CompanyName': 'ALL ONE'},
#  {'BOMId': 48,
#   'ConsumedSKU': 'RM-C2-riboflavin-a3d02436',
#   'Type': 'raw-material',
#   'CompanyName': 'ALL ONE'},
#  {'BOMId': 48,
#   'ConsumedSKU': 'RM-C2-rice-bran-1f905661',
#   'Type': 'raw-material',
#   'CompanyName': 'ALL ONE'},
#  {'BOMId': 48,
#   'ConsumedSKU': 'RM-C2-rice-protein-c17ff51d',
#   'Type': 'raw-material',
#   'CompanyName': 'ALL ONE'},
#  {'BOMId': 48,
#   'ConsumedSKU': 'RM-C2-rutin-e29ccf19',
#   'Type': 'raw-material',
#   'CompanyName': 'ALL ONE'},
#  {'BOMId': 48,
#   'ConsumedSKU': 'RM-C2-soy-lecithin-cc38c49d',
#   'Type': 'raw-material',
#   'CompanyName': 'ALL ONE'},
#  {'BOMId': 48,
#   'ConsumedSKU': 'RM-C2-thiamine-hcl-a714a4bf',
#   'Type': 'raw-material',
#   'CompanyName': 'ALL ONE'},
#  {'BOMId': 48,
#   'ConsumedSKU': 'RM-C2-vitamin-a-palmitate-58b26912',
#   'Type': 'raw-material',
#   'CompanyName': 'ALL ONE'}]

# %%
suppliers = get_suppliers()
print(f"{len(suppliers)} suppliers")
suppliers[:3]
# Out:
# 40 suppliers
# [{'Id': 1, 'Name': 'ADM'},
#  {'Id': 2, 'Name': 'AIDP'},
#  {'Id': 3, 'Name': 'Actus Nutrition'}]

# %%
supplier_products = get_supplier_products()
print(f"{len(supplier_products)} supplier-product links")
supplier_products[:5]
# Out:
# 1633 supplier-product links
# [{'SupplierId': 1,
#   'SupplierName': 'ADM',
#   'SKU': 'RM-C17-medium-chain-triglycerides-8f09d80d',
#   'Type': 'raw-material',
#   'CompanyName': 'Equate'},
#  {'SupplierId': 1,
#   'SupplierName': 'ADM',
#   'SKU': 'RM-C17-sunflower-oil-bb851f70',
#   'Type': 'raw-material',
#   'CompanyName': 'Equate'},
#  {'SupplierId': 1,
#   'SupplierName': 'ADM',
#   'SKU': 'RM-C18-digestive-enzymes-5dab88c4',
#   'Type': 'raw-material',
#   'CompanyName': 'GMU SPORT'},
#  {'SupplierId': 1,
#   'SupplierName': 'ADM',
#   'SKU': 'RM-C18-lecithin-a7f2d498',
#   'Type': 'raw-material',
#   'CompanyName': 'GMU SPORT'},
#  {'SupplierId': 1,
#   'SupplierName': 'ADM',
#   'SKU': 'RM-C2-soy-lecithin-cc38c49d',
#   'Type': 'raw-material',
#   'CompanyName': 'ALL ONE'}]

# %%
# ── Supplier batching for a product ──────────────────────────────────────────
PRODUCT_SKU = boms[0]['ProducedSKU']   # change to any finished-good SKU

result = batch(PRODUCT_SKU)

if not result['assignments'] and not result['uncovered']:
    print(f"No BOM found for {PRODUCT_SKU}")
else:
    bom_lookup = {b['ProducedSKU']: b['BOMId'] for b in boms}
    bom_id = bom_lookup.get(PRODUCT_SKU)
    components = get_bom_components(bom_id)

    # old_supplier = owning company on the component; price/quality not in DB
    old_supplier_map = {c['ConsumedSKU']: c['CompanyName'] for c in components}

    rows = []
    for c in components:
        sku = c['ConsumedSKU']
        rows.append({
            'ingredient': sku,
            'old_supplier': old_supplier_map.get(sku, 'N/A'),
            'new_supplier': result['assignments'].get(sku, '— uncovered —'),
            'old_price':   'N/A',
            'new_price':   'N/A',
            'old_quality': 'N/A',
            'new_quality': 'N/A',
        })
    rows.sort(key=lambda r: r['ingredient'])

    print(f"Product : {PRODUCT_SKU}")
    print(f"Suppliers after batching: {len(result['suppliers'])}  |  "
          f"Uncovered: {len(result['uncovered'])}\n")

    ing_w = 48
    sup_w = 22
    prc_w = 10
    qlt_w = 12
    header = (
        f"{'Ingredient':<{ing_w}} "
        f"{'Old Supplier':<{sup_w}} {'New Supplier':<{sup_w}} "
        f"{'Old Price':<{prc_w}} {'New Price':<{prc_w}} "
        f"{'Old Quality':<{qlt_w}} {'New Quality':<{qlt_w}}"
    )
    print(header)
    print('-' * len(header))
    for r in rows:
        print(
            f"{r['ingredient']:<{ing_w}} "
            f"{r['old_supplier']:<{sup_w}} {r['new_supplier']:<{sup_w}} "
            f"{r['old_price']:<{prc_w}} {r['new_price']:<{prc_w}} "
            f"{r['old_quality']:<{qlt_w}} {r['new_quality']:<{qlt_w}}"
        )
